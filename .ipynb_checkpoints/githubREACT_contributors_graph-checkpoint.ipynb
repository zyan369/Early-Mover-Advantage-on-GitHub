# %%
import requests as re
import json
import networkx as nx
import pandas as pd
from github import Github
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#variables
# myToken = '3f2a785f429c344df6ad9adeb84eb8146fe4271a'
# header = {"Accept":"application/vnd.github.squirrel-girl-preview+json",
#          "Authorization":format(myToken)}
# base_url = "https://api.github.com/"

# %%
#getting the repositories with most forks 
# repositories?q=forks:%3E100000&sort=forks&order+desc
# url_1 = "https://api.github.com/search/repositories?q=forks:%3E100000&sort=forks&order+desc"
# response1 = re.get(url_1)
# data1 = response1.json()
# # data1

# %%
#Extracting the information from the initial response

# def get_repos_contributors_list(data):
#     while(1):
#         if data["incomplete_results"]==True:
#             url_1 = "https://api.github.com/search/repositories?q=forks:%3E100000&sort=forks&order+desc"
#             response1 = re.get(url_1)
#             data = response1.json()
           
#     df1 = pd.DataFrame(columns=['repoName','repoAuthor','repoURL','forkCount', 'contributors'])   
    
#     for i in range (0,data['total_count'])):

# %% [markdown]
# ## Repository under consideration (facebook/react)

# %% [markdown]
# ### list of contributors

# %%
#the top rated repository
#http://gitmostwanted.com/

ACCESS_TOKEN = '4aa7a1c11cd00ec6d4255a9a9409007c9b6064ca'

#chosen user and the repo
USER = 'facebook'
REPO = 'facebook/react'

#Pygitgub object for further navigation
client = Github(ACCESS_TOKEN, per_page=100)
user = client.get_user(USER)
repo = client.get_repo(REPO)

#retrieve the list of contributors for REPO
contributors = [x for x in repo.get_contributors()]
print("Number of contributors: ",len(contributors))

#list of contributers
contributers_list = []
for c in contributors:
    contributers_list.append(c.login)
contributers_list
# Out:
# Number of contributors:  432
# ['zpao',
#  'gaearon',
#  'bvaughn',
#  'sophiebits',
#  'sebmarkbage',
#  'acdlite',
#  'jimfb',
#  'petehunt',
#  'trueadm',
#  'chenglou',
#  'vjeux',
#  'benjamn',
#  'yungsters',
#  'subtleGradient',
#  'nhunzaker',
#  'aweary',
#  'syranide',
#  'necolas',
#  'cpojer',
#  'flarnie',
#  'koba04',
#  'marocchino',
#  'threepointone',
#  'kohei-takata',
#  'chicoxyzzy',
#  'keyz',
#  'mcsheffrey',
#  'TheSavior',
#  'bgw',
#  'NE-SmallTown',
#  'hellendag',
#  'joshduck',
#  'aickin',
#  'jquense',
#  'Daniel15',
#  'iamdustan',
#  'philipp-spiess',
#  'Simek',
#  'fisherwebdev',
#  'fabiomcosta',
#  'sompylasar',
#  'jordwalke',
#  'raphamorim',
#  'arkist',
#  'SimenB',
#  'cody',
#  'iamchenxin',
#  'tomocchino',
#  'lunaruan',
#  'mroch',
#  'graue',
#  'ivanzotov',
#  'kmeht',
#  'DarkScorpion',
#  'bhamodi',
#  'RReverser',
#  'leebyron',
#  'lucasecdb',
#  'fxxkscript',
#  'yangshun',
#  'AnSavvides',
#  'andreypopp',
#  'clemmy',
#  'kassens',
#  'jaredly',
#  'joecritch',
#  'Andarist',
#  'raunofreiberg',
#  'rickbeerendonk',
#  'yiminghe',
#  'zertosh',
#  'camsong',
#  'hzoo',
#  'jgebhardt',
#  'SanderSpies',
#  'dittos',
#  'puradox',
#  'elas7',
#  'andrewdavey',
#  'hristo-kanchev',
#  'ianobermiller',
#  'motiz88',
#  'RaitoBezarius',
#  'alexeyraspopov',
#  'hramos',
#  'piranha',
#  'awwright',
#  'bripkens',
#  'bspaulding',
#  'brigand',
#  'jbonta',
#  'jontewks',
#  'lrowe',
#  'lyip1992',
#  'mmarkelov',
#  'makky3939',
#  'mzabriskie',
#  'matthewwithanm',
#  'mxstbr',
#  'pedronauck',
#  'Pouja',
#  'jddxf',
#  'abhaynikam',
#  'alexmckenley',
#  'clayallsopp',
#  'aaronabramov',
#  'jfo84',
#  'jbaiter',
#  'josephsavona',
#  'joshma',
#  'julen',
#  'keito',
#  'jeyraof',
#  'dalinaum',
#  'mjul',
#  'matthewjohnston4',
#  'mertkahyaoglu',
#  'mitermayer',
#  'orta',
#  'ClimbsRocks',
#  'rricard',
#  'submetu',
#  'Jessidhia',
#  'kentcdodds',
#  'rickhanlonii',
#  'af',
#  'armujahid',
#  'AlmeroSteyn',
#  'azich',
#  'avanderhoorn',
#  'bernard-lin',
#  'brianreavis',
#  'cyan33',
#  'gasi',
#  'hejld',
#  'DenrizSusam',
#  'cbrwizard',
#  'glenjamin',
#  'kchia',
#  'jeffreylin',
#  'xjlim',
#  'jonathan-beebe',
#  'monkindey',
#  'KyleAMathews',
#  'prometheansacrifice',
#  'mfunkie',
#  'mtharrison',
#  'thymikee',
#  'nmn',
#  'nateq314',
#  'ngavalas',
#  'wherestheguac',
#  'seiffert',
#  'operatino',
#  'misoguy',
#  'skiritsis',
#  'sahrens',
#  'tbroadley',
#  'troydemonbreun',
#  'volkanunsal',
#  'noyobo',
#  'remixz',
#  'mariodu',
#  'yuyokk',
#  'maciej-ka',
#  'adelevie',
#  'accordeiro',
#  'alexpien',
#  'alexzherdev',
#  'alextsg',
#  'antsmartian',
#  'anushreesubramani',
#  'ariabuckles',
#  'bobeagan',
#  'CarlMungazi',
#  'conorhastings',
#  'diegomura',
#  'mitenka',
#  'dmatteo',
#  'edvinerikson',
#  'ericnakagawa',
#  'fgnass',
#  'wincent',
#  'groodt',
#  'Haroenv',
#  'hnordt',
#  'ivan',
#  'IvanVergiliev',
#  'jtmalinowski',
#  'jergason',
#  'janhancic',
#  'jasonwilliams',
#  'bitshadow',
#  'jonhester',
#  'svenheden',
#  'KevinTCoughlin',
#  'thekevlau',
#  'lipis',
#  'markijbema',
#  'mathieumg',
#  'matiassingers',
#  'arcanis',
#  'mridgway',
#  'xixixao',
#  'mihaip',
#  'millermedeiros',
#  'enaqx',
#  'nick-thompson',
#  'nikolas',
#  'ning-github',
#  'passy',
#  'plievone',
#  'pieterv',
#  'piperchester',
#  'rwoodnz',
#  'sambev',
#  'eps1lon',
#  'shaneosullivan',
#  'tsriram',
#  'neojski',
#  'trevorsmith',
#  'Yeti-or',
#  'fson',
#  'vipulnsward',
#  'madeinfree',
#  'XuefengWu',
#  'hkal',
#  'zwhitchcox',
#  'watadarkstar',
#  'adammark',
#  'Wildhoney',
#  'pluma',
#  'drdelambre',
#  'Tom910',
#  'theKashey',
#  'aruberto',
#  'apaatsio',
#  'anmonteiro',
#  'amm385',
#  'artnez',
#  'gunn',
#  'basarat',
#  'behzad888',
#  'benhalpern',
#  'benmoss',
#  'bgirard',
#  'brandonbloom',
#  'hartzis',
#  'btholt',
#  'briankung',
#  'brianr',
#  'chentsulin',
#  'calebmer',
#  'ChrisSki',
#  'christianalfoni',
#  'monsanto',
#  'clarkdo',
#  'dschafer',
#  'dantman',
#  'djrodgerspryor',
#  'divad12',
#  'linshunghuang',
#  'dpercy',
#  'deanbrophy',
#  'dmnd',
#  'enguerran',
#  'ericflo',
#  'ehellman',
#  'Ethan-Arrowood',
#  'nutboltu',
#  'philix',
#  'fkling',
#  'montogeek',
#  'fpoumian',
#  'Hypnosphi',
#  'gscottolson',
#  'gabelevi',
#  'GantMan',
#  'garethnic',
#  'georgesisco',
#  'GordyD',
#  'grant',
#  'hendrikswan',
#  'oluckyman',
#  'jessebeach',
#  'jackson-huang',
#  'jwworth',
#  'ide',
#  'jlongster',
#  'jamesgpearce',
#  'jlfwong',
#  'jeanlauliac',
#  'JedWatson',
#  'jeffchan',
#  'jdalton',
#  'jonscottclark',
#  'ljharb',
#  'HeroProtagonist',
#  'Kachulio1',
#  'jnu',
#  'piscolomo',
#  'tae-jun',
#  'quark-zju',
#  'jdudak',
#  'fkgozali',
#  'kevinzwhuang',
#  'lacker',
#  'kevinold',
#  'karczk',
#  'kunukn',
#  'terabaud',
#  'tendant',
#  'lelandrichardson',
#  'levibuzolic',
#  'AgtLucas',
#  'Shastel',
#  'protron',
#  'marjan-georgiev',
#  'undernewmanagement',
#  'maxdeviant',
#  'mhujer',
#  'marvinhagemeister',
#  'mbrookes',
#  'michaelgmcd',
#  'michaelrp',
#  'mgol',
#  'd4rky-pl',
#  'allofthenorthwood',
#  'pekim',
#  'milesj',
#  'NMinhNguyen',
#  'mmoss',
#  'murtazahaveliwala',
#  'Nadia--',
#  'nw',
#  'nihgwu',
#  'NicBonetto',
#  'nicholasbs',
#  'WickyNilliams',
#  'oiva',
#  'Oleg24',
#  'DJCordhose',
#  'kingisaac95',
#  'javache',
#  'czajkowski',
#  'prathamesh-sonpatki',
#  'pra85',
#  'rafd',
#  'rthor',
#  'rajendraarora16',
#  'quadrupleslap',
#  'exiadbq',
#  'RichardLitt',
#  'Cartas',
#  'richiethomas',
#  'rileytomasek',
#  'darobin',
#  'robinweser',
#  'roderickhsiao',
#  'pomber',
#  'romamatusevich',
#  'him2him2',
#  'samselikoff',
#  'STRML',
#  'tux-tn',
#  'scottburch',
#  'sebmck',
#  'theseyi',
#  'yenshih',
#  'shinnn',
#  'shripadk',
#  'shubheksha',
#  'hojberg',
#  'sophiebits-humu',
#  'stkb',
#  'stoyan',
#  'fforw',
#  'sverrejoh',
#  'slorber',
#  'lasekio',
#  'taehwanno',
#  'TanaseHagi',
#  'teosz',
#  'ThomasCrevoisier',
#  'timjacobi',
#  'troutowicz',
#  'yangmillstheory',
#  'vincentriemer',
#  'vitorbal',
#  'yu-tian113',
#  'yhagio',
#  'ankitml',
#  'everdimension',
#  'gitanupam',
#  'hanumanthan',
#  '403studio',
#  'imagentleman',
#  'jinmmd',
#  'gebilaoxiong',
#  'ryota-murakami',
#  'sw-yx',
#  'msmania',
#  'zombieJ',
#  'arnihermann',
#  'cookfront',
#  '243083df',
#  '8398a7',
#  'AGCB',
#  'aackerman',
#  'getaaron',
#  'cannona',
#  'abhisheksoni27',
#  'gadtfly',
#  'rigdern',
#  'akre54',
#  'asolove',
#  'sheerun',
#  'adamzap',
#  'addyosmani',
#  'ad-si',
#  'aesopwolf',
#  'wali-s',
#  'airamrguez',
#  'alansouzati',
#  'afhole',
#  '4leem',
#  'proteriax',
#  'ultrafez',
#  'ababkov',
#  'alexbaumgertner',
#  'javawizard',
#  'xelad1']

# %% [markdown]
# ### Constructing the graph between contributors for REACT repo (who follows whom)

# %%
#Directed graph
#creating a node with contributors
DG = nx.DiGraph()
for c in contributors:
    DG.add_node(c.login,type='user')

# %%
#adding edges between contributors if followers relationship exist
for i in range (0,len(contributors)):
    followers_url = contributors[i].followers_url+'?access_token='+ACCESS_TOKEN
    response = re.get(followers_url)
    response = response.json()
    followers_list = []
    for j in range(len(response)):
        followers_list.append(response[j]['login'])
    for k in range(len(followers_list)):
        if followers_list[k] in contributers_list:
            DG.add_edge(followers_list[k], contributors[i].login,type='follows')
    
#     print(followers_url)
#     r = re.get(followers_url)
#     r = r.json()
#     for j in range (0,len(r)):
#         if r[j]['login'] in contributers_list:
#             DG.add_edge(r[j]['login'], contributors[i].login,type='follows')

# %%
print(nx.info(DG))
# Out:
# Name:
# Type: DiGraph
# Number of nodes: 432
# Number of edges: 152
# Average in degree:   0.3519
# Average out degree:   0.3519

# %%
plt.figure(figsize=(20,14))
nx.draw(DG, pos=nx.spring_layout(DG), node_color='lightblue',
    linewidths=0.25, font_size=10, font_weight='light', with_labels=True, dpi=2000)
plt.title('Contributors graph for REACT repo')
plt.show()
# plt.savefig('contributors_network.svg', format='svg', dpi=1200)
