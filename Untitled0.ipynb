# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import os

os.listdir()
# Out:
# ['.config', 'sample_data']

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
os.chdir("drive")
os.chdir("My Drive")
os.chdir("Colab Notebooks")

# %%
pdd = pd.read_csv('folcol.csv', header=None)
pdd.columns =['user_ID', 'follower_ID']

# %%
uf= pd.DataFrame(pd.pivot_table(pdd, index='user_ID', values='follower_ID'))
uf
# Out:
#            follower_ID
# user_ID
# 0         1.000000e+00
# 1         8.138271e+05
# 2         1.380899e+06
# 4         1.420546e+06
# 5         2.243200e+04
# ...                ...
# 46498185  1.008780e+05
# 46498187  2.917341e+06
# 46498190  1.158888e+07
# 46498191  2.611918e+06
# 46498192  4.924379e+06
#
# [3833653 rows x 1 columns]

# %%
sorted(uf['follower_ID'], reverse=True)[:5]
# Out:
# [46497063.0, 46496858.0, 46496489.0, 46496488.0, 46495287.0]

# %%
#a = []
#while(1):
#    a.append(1)
#!cat /var/log/colab-jupyter.log
#import json

#with open("/var/log/colab-jupyter.log", "r") as fo:
#  for line in fo:
#   print(json.loads(line)['msg'])"

# %%
pdd.head()
# Out:
#    user_ID  follower_ID
# 0        0            1
# 1        1            2
# 2        1            4
# 3        1        17896
# 4        1        21523

# %%
G = nx.from_pandas_edgelist(pdd, 'user_ID','follower_ID')

# %%
G

# %%
del pdd

# %%
pr = nx.pagerank(G, alpha=0.9)

# %%
pr
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-07c73c38aafa> in <module>()
# ----> 1 pr
#
# NameError: name 'pr' is not defined

# %%
import matplotlib.pyplot as plt
plt.figure(figsize =(10, 10)) 
nx.draw(G)#, with_labels=True)
plt.show()

# %%
G=nx.dodecahedral_graph()
nx.draw(G)
nx.draw(G,pos=nx.spring_layout(G)) # use spring layout

limits=plt.axis('off') # turn off axis

# %%
plt.figure(figsize =(10, 10)) 
nx.draw_networkx(G, with_labels = True)

# %%
hubs, authorities = nx.hits(G, max_iter = 1, normalized = True) 
# The in-built hits function returns two dictionaries keyed by nodes 
# containing hub scores and authority scores respectively. 
  
print("Hub Scores: ", hubs) 
print("Authority Scores: ", authorities)
# Out:
# ---------------------------------------------------------------------------
# PowerIterationFailedConvergence           Traceback (most recent call last)
# <ipython-input-8-8eb1a4f7d1f0> in <module>()
# ----> 1 hubs, authorities = nx.hits(G, max_iter = 1, normalized = True)
#       2 # The in-built hits function returns two dictionaries keyed by nodes
#       3 # containing hub scores and authority scores respectively.
#       4
#       5 print("Hub Scores: ", hubs)
#
# /usr/local/lib/python3.6/dist-packages/networkx/algorithms/link_analysis/hits_alg.py in hits(G, max_iter, tol, nstart, normalized)
#     116             break
#     117     else:
# --> 118         raise nx.PowerIterationFailedConvergence(max_iter)
#     119     if normalized:
#     120         s = 1.0 / sum(a.values())
#
# PowerIterationFailedConvergence: (PowerIterationFailedConvergence(...), 'power iteration failed to converge within 1 iterations')

# %%
h,a=nx.hits(G)

# %%
h

# %%
a

# %%
deg_centrality = nx.degree_centrality(G)

# %%
type(deg_centrality)
# Out:
# dict

# %%
deg_centrality[10]
# Out:
# 0.000539812170662492

# %%
sorted(deg_centrality.items(), key = lambda kv:(kv[1], kv[0]), reverse = True)[:10]
# Out:
# [(1302201, 0.054787401059237226),
#  (13330706, 0.04440448040381373),
#  (5045042, 0.03662259130675469),
#  (5956845, 0.031032503314766674),
#  (33579752, 0.030050164213020078),
#  (1640412, 0.02614963995160664),
#  (6295826, 0.022111651460655097),
#  (208598, 0.02109210959042728),
#  (3688872, 0.020133766274351074),
#  (5203, 0.01771930659991994)]

# %%
G.is_directed()
# Out:
# False

# %%
G.nodes()

# %%
G.number_of_edges()
# Out:
# 27302897

# %%
G.number_of_nodes()
# Out:
# 5375945

# %%
G.size()
# Out:
# 27302897

# %%
G.order()
# Out:
# 5375945

# %%
nx.average_clustering(G)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-952a7716f836> in <module>()
# ----> 1 nx.average_clustering(G)
#
# /usr/local/lib/python3.6/dist-packages/networkx/algorithms/cluster.py in average_clustering(G, nodes, weight, count_zeros)
#     257        https://arxiv.org/abs/0802.2512
#     258     """
# --> 259     c = clustering(G, nodes, weight=weight).values()
#     260     if not count_zeros:
#     261         c = [v for v in c if v > 0]
#
# /usr/local/lib/python3.6/dist-packages/networkx/algorithms/cluster.py in clustering(G, nodes, weight)
#     362             td_iter = _triangles_and_degree_iter(G, nodes)
#     363             clusterc = {v: 0 if t == 0 else t / (d * (d - 1)) for
# --> 364                         v, d, t, _ in td_iter}
#     365     if nodes in G:
#     366         # Return the value of the sole entry in the dictionary.
#
# ...

# %%
list(nx.connected_components(G))

# %%
sorted(d for n, d in G.degree())

# %%
Graph.to_directed()
